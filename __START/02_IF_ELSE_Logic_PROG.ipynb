# %% [markdown]
# **if else** logic is for running code based on condition being True of False
#
# - **comparison operators** evaluate a **condition** by comparing two values
# - the comparison returns a **boolean** (True or False)
# - comparison operators:
#   - a == b returns True if a and b are equal
#   - a < b returns True if a is less than b
#   - a > b returns True if a is greater than b
#   - a <= b returns True if a is less than or equal to b
#   - a >= b returns True if a is greater than or equal to b
#   - a != b returns True if a and b are not equal

# %%
# import pretty print so we do not have to scroll sideways for long output
import pprint as pp

# %%
#  Comparison Operators
# check len() of strings and list
# check first/last char of string
# check first/last item of list
pets = ['bunny', 'cat', 'dog']
print(len(pets) == 4) # False
print(len(pets[0]) != 4) # True -- pets[0] 'bunny' has 5 letters

print(len(pets[-1]) > 1) # > (greater than check)
print(len(pets[1]) < 1) # < (less than check)
print(len(pets) == 10) # == (equality check)
print(len(pets) != 10) # != (inequality check)

print() # [0] (list item check)
print() # [-1] (list item check)
print() # [0] (str char check)
print() # [-1] (str char check)
# Out:
# False
# True
# True
# False
# False
# True

# %% [markdown]
# ### if comparisons:
# - the keyword **if** followed by a boolean comparison
# - if pet == "cat":
# - if x > 3:
# - if len(pet) != 5:
#
# - end the if boolean with a colon:
# - the next line of code will auto-indent
# - the code inside the if block runs only IF the condition is True
# - if pet == "cat":
#   - print('Meow!')

# %%
pets = ['bunny', 'cat', 'dog']
# code inside an if block runs if AND ONLY IF condition is True
# condition is False
pet = pets[-1]
print('pet:',pet)

if pet == 'bunny': # False
  print('Pet is a bunny..!!') # does not run

if pet != 'bunny': # True
  print('Pet is not a bunny') # runs!
# Out:
# pet: dog
# Pet is not a bunny

# %% [markdown]
# ### **else** runs if condition is False

# %% [markdown]
# ### **elif** evaluates a second condition

# %%
# condition is False
pets = ['bunny', 'cat', 'dog']

if pet == 'bunny': # False
  print('Pet is a bunny..!!') # does not run
else:
  print('Pet is not a bunny') # runs!

# compare len pets list to len 2nd pet:
pet = pets[1] # cat
if len(pets) == len(pet):
  print(f'list pets and string "{pet}" are same length')
else:
  print(f'list pets and string "{pet}" are NOT same length..!')

# same as previous, but make conditon False:
pet = pets[0] # bunny
if len(pets) == len(pet):
  print(f'list pets and string "{pet}" are same length')
else:
  print(f'list pets and string "{pet}" are NOT same length..!')

# challenge TWO if-else blocks using this list to eval condition
fruits = ['apple', 'banana', 'cherry', 'grape', 'kiwi']
# FIRST time make condition True, so if part runs
# SECOND time, make condition False, so else part runs
fru = fruits[1] # 'banana'
if len(fruits) > len(fru):
  print(f'list fruit length greater than string "{fru}" length')
else:
  print(f'list fruit length NOT greater than string "{fru}" length')
# Out:
# Pet is a bunny..!!
# list pets and string "cat" are same length
# list pets and string "bunny" are NOT same length..!
# list fruit length NOT greater than string "banana" length

# %%
price = float(input("Price: "))
# make an input("Price: ")

# save the inputted price to a variable
# convert price to number
print('price:', price)

# if the price is less than 10,
# print: "Price is cheap"
# else
# print "Price is expensive"
if price < 10:
  print(f"Price {price} is cheap")
  print("Price " + str(price) + " is cheap")
  print("Price {price} is cheap") # fails to eval var
# elif means else if; use elif to eval a SECOND condition
# if the first condition -- the if -- is False
elif price < 20:
  print(f"Price {price} is reasonable")
else:
  print(f"Price {price} is expensive")
# Out:
# Price: 0
# Price: 1
# price: 1.0
# Price 1.0 is cheap
# Price 1.0 is cheap
# Price {price} is cheap

# %%
price = float(input("Price: "))
# use if - elif - elif - else to check the price
# if price is 0, print "Free"
# else if price is less than 10, print "Cheap"
# else if price is less than 20, print "Reasonable"
# else print "Expensive"
if price == 0:
  print(f"Price {price} is free")
elif price < 10:
  print(f"Price {price} is cheap")
elif price < 20:
  print(f"Price {price} is reasonable")
else:
  print(f"Price {price} is expensive")
# Out:
# Price: 0
# Price 0.0 is free

# %% [markdown]
# ### multiple conditions with and or
# - **and** 2 conditions must both be true
#     - **condition1 and condition2**
# - **or** 1 of 2 conditions must be true
#     - **condition1 or condition2**

# %%
# AND:
# consider two conditions: price and how much money I have
# idea being you must have enough money -- reasonable price not enough
# if price is reasonable (or better), we want to buy it
# BUT if my_money is less than 100 -- oops! I CANNOT BUY IT
my_money = 100
# reasonable we will buy it if we have enough money
price = float(input("Price: "))

# check BOTH conditions with "and" -- BOTH MUST be True for if part to run
if price <= 100 and my_money >= 100:
  print("I have enough money! I'll take it!")
else: # runs if EITHER condition is False
  print("Can't buy it!")
# Out:
# Price: 1
# I have enough money! I'll take it!

# %%
# another example with and: evaluate TWO conditions,
# both of which must be True in order to run the if part:
pets = 'bunny', 'cat', 'dog'
print(pets, type(pets))
print(pets[0])
# L@@K! If you declare a list but forget the [], and just
# have some loosies, then you do not get a list--you get a tuple
# a tuple is another kind of collection BUT unlike a list, a
# tuple is immutable--you can't append, pop, insert of nuthin'
# the telltale sign of a tuple is () parentheses instead of []
# Out:
# ('bunny', 'cat', 'dog') <class 'tuple'>
# bunny

# %%
# if there are less than 5 pets, and the last pet 'dog',
# add 'hamster' to the end of the list:
pets = ['bunny', 'cat', 'dog']
if len(pets) < 5 and pets[-1] == 'dog':
  pets.append('hamster')

print(pets)
# Out:
# ['bunny', 'cat', 'dog', 'hamster']

# %%
# OR: only ONE of TWO conditions must be true
# if pets list has less than 3 items (False)
# or 2nd pet is 'cat',
# add "tarantula" to end of list
if len(pets) < 3 or pets[1] == 'cat':
  pets.append('tarantula')

print(pets)
# Out:
# ['bunny', 'cat', 'dog', 'hamster', 'tarantula']

# %%
if len(pets) < 3 or pets[-1] == 'tarantula':
  pets.append('turtle')

print(pets)
# Out:
# ['bunny', 'cat', 'dog', 'hamster', 'tarantula', 'turtle']

# %%
if len(pets) < 3 or pets[1] == 'cat':
  pets.append('iguana')

print(pets)
# Out:
# ['bunny', 'cat', 'dog', 'hamster', 'tarantula', 'turtle', 'iguana', 'iguana', 'iguana', 'iguana', 'iguana', 'iguana']

# %%
fruits = ['apple', 'banana', 'cherry', 'grape', 'kiwi', 'lime']

# %%
# challenge: print the length of the first fruit in fruits list (5):
print(fruits[0])
print(len(fruits[0]))
# Out:
# apple
# 5

# %%
fruits = ['apple', 'banana', 'cherry', 'grape', 'kiwi', 'lime']
print(fruits)

# challenge A: if there are EXACTLY SIX (6) fruits,
# add "lemon" to the end of the list, and print the updated list
if len(fruits) == 6:
  fruits.append('lemon')
else:
  print("Oops! Already have more than 6 fruits!")

print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'grape', 'kiwi', 'lime']
# ['apple', 'banana', 'cherry', 'grape', 'kiwi', 'lime', 'lemon']

# %%
# ['apple', 'banana', 'cherry', 'grape', 'kiwi', 'lime', 'lemon']
# challenge B: if the first fruit is apple and the last fruit is lemon
# add orange and peach to the end:
# and print the updated list
# HINT: extend
# 'apple' 'lemon'
# 'orange', 'peach'

if fruits[0] == 'apple' and fruits[-1] == 'lemon':
  fruits.extend(['orange', 'peach'])

print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'grape', 'kiwi', 'lime', 'lemon', 'orange', 'peach']

# %%
# challenge C: or operator requires just one of multiple conditions to be true
# if first fruit is 'blueberry' OR there are at less than 12 fruits,
# add 'apricot' to the beginning as the new first item, without losing apple
# and print the updated list
if fruits[0] == 'blueberry' or len(fruits) < 12:
  fruits.insert(0,'apricot')
# HINT: insert
# 'blueberry'
# 'apricot'
# L@@K: this can be re-run to get up to 3 apricots--then it becomes both False
print(fruits)
# Out:
# ['apricot', 'apricot', 'apricot', 'apple', 'banana', 'cherry', 'grape', 'kiwi', 'lime', 'lemon', 'orange', 'peach']

# %% [markdown]
# - **str.startswith("bl")** checks if string starts with "bl" and returns boolean (True or False)
# - **str.endswith("ly")** checks if string ends with "ly" and returns boolean (True or False)
# - this is an alternative to checking at index:
# - **str[:2] == "bl"** checks if string starts with "bl" and returns boolean
# - **str[-2:] == "ly"** checks if string ends with "ly" and returns boolean
# - startswith / endswith provides more flexibility than checking at index, since it aceepts more than on char without specifying start:end range

# %%
fruits = ['apricot', 'apple', 'banana', 'cherry', 'grape', 'kiwi', 'lime', 'lemon', 'orange', 'peach']

# str.startswith(char) instead str[0] == char
# both return boolean
# first fruit is apricot:
# first letter of apricot is 'a'
print(fruits[0]) # apricot
print(fruits[0][0]) # a
print(fruits[0][0] == 'a') # True
print(fruits[0].startswith('a')) # True

print(fruits[3]) # cherry
print(fruits[3][0]) # c
print(fruits[3][-1]) # y
print(fruits[3][-1] == 'y') # True
print(fruits[0].endswith('a')) # True

# how can Python check if the last word in this list ends with 'h'
# I see that the last word is 'peach', which ends in 'h'
# BUT I want the Python way!
print(fruits[-1][-1] == 'h')
# Out:
# apricot
# a
# True
# True
# cherry
# c
# y
# True
# False
# True

# %%
# CHALLENGE: combine "and" with "or":
# (if the first fruit is "blueberry" OR there are less
# than 12 fruits) AND last fruit starts with "p"
# if all THAT is True, add 'kumquat' right after 'kiwi'

# if (condition1 or condition2) and condition3:
  # do stuff


# fruit.insert(fruit.index('kiwi')+1,'kumquat')
# Out:
# ['apricot', 'apple', 'banana', 'cherry', 'grape', 'kiwi', 'kumquat', 'kumquat', 'kumquat', 'lime', 'lemon', 'orange', 'peach']

# %% [markdown]
# - **nested conditional logic:** an if inside an if

# %%
fruits = ['apricot', 'apple', 'banana', 'cherry', 'grape', 'kiwi', 'lime', 'lemon', 'orange', 'peach']

# NEW list method: extend()
# list1.extend(list2+list3)
berries = ['blueberry', 'raspberry', 'strawberry']
p_fruits = ['papaya', 'pear', 'plum', 'pineapple']
# add berries and p_fruits to the fruits list at the end
fruits.extend(berries + p_fruits)
# sort the resulting long list:
fruits.sort()
pp.pprint(fruits)
# Out:
# ['apple',
#  'apricot',
#  'banana',
#  'blueberry',
#  'cherry',
#  'grape',
#  'kiwi',
#  'lemon',
#  'lime',
#  'orange',
#  'papaya',
#  'peach',
#  'pear',
#  'pineapple',
#  'plum',
#  'raspberry',
#  'strawberry']

# %% [markdown]
# ### **in** and **not in**
# - checks for *existence* of item in list
# - returns a *boolean*
# ```python
# print('apple' in fruits) # True
# print('bunny' in fruits) # False
# print('apple' not in fruits) # False
# print('bunny' not in fruits) # True
# ```

# %% [markdown]
# ### **str.lower()** and **str.upper()**
# - string methods
# - returns a lowercase or uppercase version of the string
# - set equal to itself to save the result
# ```python
# # lowercase the word
# word = word.lower()
# ```

# %%
more_fruits = ['mango', 'avocado', 'watermelon', 'coconut', 'grapefruit', 'pomegranate', 'persimmon', 'cranberry', 'fig', 'date', 'dragonfruit']

# %%
# CHALLENGE B: make an input for making a fruit treat
# user enters a fruit from the fruits list and gets a treat
# if-elif-elif-else
# print("Enter an eligible fruit, get a treat!")

word = input("Enter a fruit, get a treat: ")
word = word.lower() # lowercase and save
# before making the correct treat, according to the rules
# check if the inputted word is in the fruits list
# check if the word in in the more_fruits list
# if it is NOT in either list, reject (print some appropriate msg)
# if word is in more_fruits, add it to fruits and print updated list
# then proceed to make the treat, using the fruit:
if word not in fruits:
  print(f'"{word}" is not in fruits list! Try again!')
# elif word[0] == 'p':
elif word.startswith('p'):
  print(word + " popsicle")
# else if the fruit starts with a 'p' make a popsicle:
# if the user types 'pineapple', print 'pineapple popsicle'
elif len(word) == 5:
  print(word + " jelly")
# else if the fruit has exactly 5 letters, make a jelly: 'apple jelly'
# elif word.endswith('berry'):
elif word[-5:] == 'berry':
  print(word + " jam")
# else if the fruit ends with 'berry', make jam: 'strawberry jam'
# elif fruit.endswith('berry'):
# print(" jam")
else:
  print(word + " lollipop")
# else if none of the above is true, make a lollipop: 'kiwi lollipop'

print(word) # lowercasing was not saved or persisted to word
# Out:
# Enter a fruit, get a treat: Apple
# apple jelly
# apple
