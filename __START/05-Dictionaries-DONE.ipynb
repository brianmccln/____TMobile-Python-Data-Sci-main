# %%
# import
import pprint as pp
from IPython.display import Image

# %% [markdown]
# ## **Dictionaries**
# - **collection** is an iterable data structure that includes:
#   - **lists** - multiple items in [] stored by index num position
#   - **sets** -  multiple items in {}, no index, no duplicates
#   - **dictionaries** -  multiple properties as key-value pairs in {}
#   - **tuples** - store multiple values in () and are immutable; have index

# %%
# Declare a dictionary and give it a bunch of properties as key:value pairs
# Keys must go in quotes, values can be of any data type -- incl dictionary
pet = "cat"
age = 3 # must be stringified as str(age) or it will throw ERROR
sound = "Meow!"
name = "Fluffy"
toys = ['ball of yarn', 'floppy fish', 'catnip pouch', 'slipper', 'scratch post', 'bell', 'dog bed']

# %%
# make a pet dictionary with data same as above
# dict properties exist as "key":value pairs, with keys in quotes
# : separates key from value
# value can be any data type -- including another dictionary
# keys can have spaces in names !!
pet_dict = {
    "type": "cat",
    "name": "Fluffy",
    "age": 3,
    "sound": "meow",
    "toys": ['ball of yarn', 'floppy fish', 'catnip pouch', 'slipper', 'scratch post', 'bell', 'dog bed'],
    "cute": True,
    "cute": False, # new identical key name overwrites previous one
    "has job": False,
    "owner": {
        "first_name": "Brian", 
        "last_name": "McClain",
        "has job": True,
    }
}

# %%
# output individual property values: dict["key"] returns value
print(pet_dict["type"])
print(pet_dict["name"])
print(pet_dict["has job"])
print(pet_dict["toys"])
print(pet_dict["toys"][0]) # get first toy of toys property list
# access properties of inner dictionary with double square brackets:
print(pet_dict["owner"])
print(pet_dict["owner"]["has job"])
# Out:
# cat
# Fluffy
# False
# ['ball of yarn', 'floppy fish', 'catnip pouch', 'slipper', 'scratch post', 'bell', 'dog bed']
# ball of yarn
# {'first_name': 'Brian', 'last_name': 'McClain', 'has job': True}
# True

# %%
# challenge:
# make a car dictionary with the following keys: 
# "make", "model", "options", "year", "color", "miles"
# BONUS: add city and hwy mpg as child dictionary

car = {
  "make": "Ford",
  "model": "Mustang GT",
  "year": 2025,
  "color": "White",  
  "miles": 5000,
  "options": ["mag wheels", "sports package", "spoiler", "leather seats"],
  "mpg": {"city": 18, "hwy": 24}
}
 
print(car["make"])
print(car["model"])
print(car["year"])
print(car["color"])
print(car["options"][1]) # sports package
print(car["mpg"]["hwy"]) # 24
# keys can have spaces (so not exactly same as regular variables)
# key values can be of any data type (including lists or child dicts)
# 'mag wheels', 'sports package', 'spoiler', 'flame decals'
# Out:
# Ford
# Mustang GT
# 2025
# White
# sports package
# 24

# %%
# CHALLENGE A: 
# Set (UPDATE) a property value is just like Getting (READING)
# except you are setting it equal to some new value
# add a new option, "sun roof" but do so dynamically 
car["options"].append("sun roof")
# add a new key: "for sale" set to True
car["for sale"] = True

# %%
pp.pprint(car)
# Out:
# {'color': 'White',
#  'for sale': True,
#  'make': 'Ford',
#  'miles': 5000,
#  'model': 'Mustang GT',
#  'mpg': {'city': 18, 'hwy': 24},
#  'options': ['mag wheels',
#              'sports package',
#              'spoiler',
#              'leather seats',
#              'sun roof'],
#  'year': 2025}

# %%
# # CHALLENGE B: 
# flip the "for sale" boolean (to its opposite without having to know the current value)
car["for sale"] = not car["for sale"]

# %%
pp.pprint(car)
# Out:
# {'color': 'White',
#  'for sale': False,
#  'make': 'Ford',
#  'miles': 5000,
#  'model': 'Mustang GT',
#  'mpg': {'city': 18, 'hwy': 24},
#  'options': ['mag wheels',
#              'sports package',
#              'spoiler',
#              'leather seats',
#              'sun roof'],
#  'year': 2025}

# %%
# DELETE a property using del keyword:
# add "on road" and "doors" properties and then delete them
car["on road"] = True
car["doors"] = 2
pp.pprint(car)
# Out:
# {'color': 'White',
#  'doors': 2,
#  'for sale': False,
#  'make': 'Ford',
#  'miles': 5000,
#  'model': 'Mustang GT',
#  'mpg': {'city': 18, 'hwy': 24},
#  'on road': True,
#  'options': ['mag wheels',
#              'sports package',
#              'spoiler',
#              'leather seats',
#              'sun roof'],
#  'year': 2025}

# %%
del car["doors"]
del car["on road"]

# %%
pp.pprint(car)
# Out:
# {'color': 'White',
#  'for sale': False,
#  'make': 'Ford',
#  'miles': 5000,
#  'model': 'Mustang GT',
#  'mpg': {'city': 18, 'hwy': 24},
#  'options': ['mag wheels',
#              'sports package',
#              'spoiler',
#              'leather seats',
#              'sun roof'],
#  'year': 2025}

# %%
# delete but save using pop
# "miles"

# %%
# sa

# %%
# "miles"

# %%
# pp

# %%
# put pack saved and deleted prop:
# "miles"

# %%
# pp

# %%
# CREATE Add a new property the same way you set existing propery
# adding props outside the declaration {} is done w = not :
# "doors"
# pp

# %%
# Challenge: Add 3 new options: "sub woofers" & "CD player" & "flame decals"
# then alphabetize the options:
# "sub woofers","CD player","flame decals"

# %%
# "options"
# pp

# %%
# challenge: add "engine" as key, the value of which is dictionary
# engine dict has 3 keys: "hp", "ltr", "cyl" (respective values: 260, 5.0, 8)
# "engine"
# get hp to make sure it worked
# += 1 incrementor operator -= 1
car["engine"] = {
    "hp": 260,
    "ltr": 5.0,
    "cyl": 8
    }
 
print(car["engine"]["hp"])
car["engine"]["hp"] += 1
print(car["engine"]["hp"])
car["engine"]["hp"] -= 1
print(car["engine"]["hp"])
# Out:
# 260
# 261
# 260

# %%
# pp

# %%
# increase miles by 10%
car["miles"] = int(car["miles"] * 1.1)
pp.pprint(car)
# Out:
# {'color': 'White',
#  'engine': {'cyl': 8, 'hp': 260, 'ltr': 5.0},
#  'for sale': False,
#  'make': 'Ford',
#  'miles': 5500,
#  'model': 'Mustang GT',
#  'mpg': {'city': 18, 'hwy': 24},
#  'options': ['mag wheels',
#              'sports package',
#              'spoiler',
#              'leather seats',
#              'sun roof'],
#  'year': 2025}

# %%
# Changing Key Names cannot be done directly
# Instead make a new key of the name you want
# Set its value equal to the key you don't like
# Then with the data successfully copied to new key
# Delete the unwanted original
car["odometer"] = car["miles"]
# change "miles" key to "odometer"
# first, make odometer property, the value being miles
# "odometer"
del car["miles"]
# now that miles value is copied over, delete original
# "miles"
pp.pprint(car)
# Out:
# {'color': 'White',
#  'engine': {'cyl': 8, 'hp': 260, 'ltr': 5.0},
#  'for sale': False,
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'mpg': {'city': 18, 'hwy': 24},
#  'odometer': 5500,
#  'options': ['mag wheels',
#              'sports package',
#              'spoiler',
#              'leather seats',
#              'sun roof'],
#  'year': 2025}

# %%
# delete item in list by name: 
# get rid of 'spoiler' from options:
car["options"].remove("spoiler")
pp.pprint(car)
# Out:
# {'color': 'White',
#  'engine': {'cyl': 8, 'hp': 260, 'ltr': 5.0},
#  'for sale': False,
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'mpg': {'city': 18, 'hwy': 24},
#  'odometer': 5500,
#  'options': ['mag wheels', 'sports package', 'leather seats', 'sun roof'],
#  'year': 2025}

# %%
# you can also pop the unwanted property and use
# that as the value of the new key
# this way only takes one line of code:
# replace "for sale" with "for_sale"
car["for_sale"] = car.pop("for sale")
pp.pprint(car)
# Out:
# {'color': 'White',
#  'engine': {'cyl': 8, 'hp': 260, 'ltr': 5.0},
#  'for_sale': False,
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'mpg': {'city': 18, 'hwy': 24},
#  'odometer': 5500,
#  'options': ['mag wheels', 'sports package', 'leather seats', 'sun roof'],
#  'year': 2025}

# %% [markdown]
# **combinging 2+ dictionaries into one**
# - **dict1.update(dict2)**
# - **car.update(owner)**
#     - does not nest owner under a key like "owner"
#     - instead, it adds each key-value pair from the owner dictionary directly to car's top level.
# - to add the owner dictionary as a nested dictionary under the key "owner", then do this instead:
#     - **car["owner"] = owner**

# %%
# dict1.update(dict2)
owner = {
    "first_name": "Brian", 
    "last_name": "McClain",
    "email": "brian@nobledesktop.com",
    "original owner": False
}

# %%
# car.update(owner)
car["owner"] = owner
pp.pprint(car)
# Out:
# {'color': 'White',
#  'engine': {'cyl': 8, 'hp': 260, 'ltr': 5.0},
#  'for_sale': False,
#  'make': 'Ford',
#  'model': 'Mustang GT',
#  'mpg': {'city': 18, 'hwy': 24},
#  'odometer': 5500,
#  'options': ['mag wheels', 'sports package', 'leather seats', 'sun roof'],
#  'owner': {'email': 'brian@nobledesktop.com',
#            'first_name': 'Brian',
#            'last_name': 'McClain',
#            'original owner': False},
#  'year': 2025}

# %%
# do the operation in reverse to get back to "odometer"

# %%
# pp

# %%
# Make a list of the keys
car_keys = list(car.keys())
pp.pprint(car_keys)
# make a list of the values

# pp
# Out:
# ['make',
#  'model',
#  'year',
#  'color',
#  'options',
#  'mpg',
#  'engine',
#  'odometer',
#  'for_sale',
#  'owner']

# %%
# Loop the dict key by key:
for key in car:
  # print each key and its value
  print(key, car[key])
# Out:
# make Ford
# model Mustang GT
# year 2025
# color White
# options ['mag wheels', 'sports package', 'leather seats', 'sun roof']
# mpg {'city': 18, 'hwy': 24}
# engine {'hp': 260, 'ltr': 5.0, 'cyl': 8}
# odometer 5500
# for_sale False
# owner {'first_name': 'Brian', 'last_name': 'McClain', 'email': 'brian@nobledesktop.com', 'original owner': False}

# %%
# Loop the dict by key and value:
for key, val in car.items():
  # print each key and its value
  print(key,val)
# Out:
# make Ford
# model Mustang GT
# year 2025
# color White
# options ['mag wheels', 'sports package', 'leather seats', 'sun roof']
# mpg {'city': 18, 'hwy': 24}
# engine {'hp': 260, 'ltr': 5.0, 'cyl': 8}
# odometer 5500
# for_sale False
# owner {'first_name': 'Brian', 'last_name': 'McClain', 'email': 'brian@nobledesktop.com', 'original owner': False}

# %%
# a string can be looped -- so strings are iterables
word = "elephant"
# loop word letter by letter
for char in word:
    # if first letter is a vowel, add: " is a VOWEL" after letter
    if char[0] in "aeiou":
        print(char + " is a VOWEL")
    else:
        print(char)

# look up scrabble value of each letter as we loop...
# "aeiou"
print()
print("Scrabble value: \n")
# Out:
# e is a VOWEL
# l
# e is a VOWEL
# p
# h
# a is a VOWEL
# n
# t
#
# Scrabble value:

# %%
Image("../img/scrabble.jpg",width="400")

# %%
# Scrabble word score checker challenge:
scrabble_letter_values = {
    "A": 1, "B": 3, "C": 3, "D": 2, "E": 1,
    "F": 4, "G": 2, "H": 4, "I": 1, "J": 8,
    "K": 5, "L": 1, "M": 3, "N": 1, "O": 1,
    "P": 3, "Q": 10, "R": 1, "S": 1, "T": 1,
    "U": 1, "V": 4, "W": 4, "X": 8, "Y": 4,
    "Z": 10, " ": 0, "-": 0
}

# %%
# CHALLENGE LAB: continuing w the above, declare a var for keeping score
score = 0 # scrabble score
# make an input where the player enters a word
my_word = input("Enter word, get Scrabble score: ")

# loop the word letter by letter
for letter in my_word:
    letter = letter.upper()
    # look up each letter's scrabble letter value
    letter_value = scrabble_letter_values[letter]
    print(letter, letter_value)
    score += letter_value # add letter value to the score
    # all in one line
    # score += scrabble_letter_values[letter.upper()]

print(f"Word: {my_word}, Scrabble Score: {score}")
# Out:
# F 4
# S 1
# A 1
# D 2
# F 4
# Word: fsadf, Scrabble Score: 12

# %% [markdown]
# - **dict.get("key")** vs **dict["key"]**
# - get will not throw error if key does not exist

# %%
# this works only where key exists
# if no such key, we get error
print(car["make"]) # Ford
# print(car["makeover"]) # KeyError: 'mackerel'
# Out:
# Ford

# %%
print(car.get("make")) # Ford
print(car.get("makeover")) # None
# can assign default value if key does not exist
print(car.get("makeover", "pending"))
# Out:
# Ford
# None
# pending

# %%
scrabble_letter_values["Cat"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 scrabble_letter_values["Cat"]
#
# KeyError: 'Cat'

# %%
# another way, is to save each individual letter score to a list
# and then get the sum of the list nums when done
# "Enter word, get Scrabble score: "


print("Scrabble value: ")
print()
# Out:
# Scrabble value:
